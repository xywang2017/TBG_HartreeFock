# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# np.NaN means non-convergent or no clear magnetic subbands
gaps2 = np.array([[i/2 for i in range(7)],
         [20.64,13.80,14.34,13.00,13.04,22.13,14.84]])

gaps25 = np.array([[2*i/5 for i in range(10)],
         [19.39,11.85,13.23,12.49,2.85,2.11,21.81,13.54,2.25,3.20]])

gaps25 = np.hstack([gaps25,np.array([[1.4,1.8,3.0],[4.19,14.99,17.25]])])

gaps3 = np.array([[i/3 for i in range(10)],
         [18.85,10.94,12.88,12.30,14.46,16.37,2.23,21.95,14.81,19.91]])

gaps4 = np.array([[i/4 for i in range(13)],
         [17.11,8.26,10.75,10.52,9.17,11.23,15.01,3.4,9.19,20.00,16.43,1.76,20.51]])

gaps5 = np.array([[i/5 for i in range(16)],
         [17.00,7.56,10.27,10.00,12.51,8.59,12.08,14.64,2.39,3.65,9.41,19.27,17.54,1.14,0.59,20.27]])

gaps6 = np.array([[i/6 for i in range(19)],
         [16.85,6.94,9.74,9.48,0.18,12.66,7.98,12.65,14.02,1.15,0.06,1.47,9.49,18.29,18.10,1.39,1.45,0.06,19.63]])

gaps8 = np.array([[i/8 for i in range(25)],
         [15.41,4.76,7.54,7.11,0.18,1.12,0.74,11.66,6.06,10.96,11.42,2.22,1.08,4.82,1.52,1.48,7.85,14.99,17.04,2.18,1.06,0.81,0.57,0.002,15.85]])

gaps10 = np.array([[i/10 for i in range(16)],
        [15.61,4.41,6.78,6.63,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,5.82,13.05,10.49,2.62,1.88,np.NaN]])

# %%
fig = plt.figure(figsize=(6,4))
rat = 3
plt.axvline(0,ls=":",c="gray")
plt.axvline(1,ls=":",c="gray")
plt.axvline(2,ls=":",c="gray")
plt.axvline(3,ls=":",c="gray")
plt.scatter(gaps2[0], np.ones(gaps2.shape[1])/2, s=gaps2[1]**2/rat)
plt.scatter(gaps25[0], np.ones(gaps25.shape[1])/5*2, s=gaps25[1]**2/rat)
plt.scatter(gaps3[0], np.ones(gaps3.shape[1])/3, s=gaps3[1]**2/rat)
plt.scatter(gaps4[0], np.ones(gaps4.shape[1])/4, s=gaps4[1]**2/rat)
plt.scatter(gaps5[0], np.ones(gaps5.shape[1])/5, s=gaps5[1]**2/rat)
plt.scatter(gaps6[0], np.ones(gaps6.shape[1])/6, s=gaps6[1]**2/rat)
plt.scatter(gaps8[0], np.ones(gaps8.shape[1])/8, s=gaps8[1]**2/rat)
# plt.scatter(gaps10[0], np.ones(gaps10.shape[1])/10, s=gaps10[1]**2/rat)
plt.xlabel(r"$\nu$")
plt.ylabel(r"$\phi/\phi_0$")

plt.xlim(-0.3,4)
plt.ylim(0,0.6)
plt.show()

# %%
fig = plt.figure(figsize=(6,4)) 
plt.scatter([2,2],[1,1],s=[100**2,50**2],c=["r","g"])
plt.show()

# %%
([3,1
            ])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_251819/2749738747.py in <module>
# ----> 1 gaps25.append([3,1
#       2             ])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'append'

# %%
np.hstack([gaps25,np.array([[3.0],[17.25]])])
# Out:
# array([[ 0.  ,  0.4 ,  0.8 ,  1.2 ,  1.6 ,  2.  ,  2.4 ,  2.8 ,  3.2 ,
#          3.6 ,  3.  ],
#        [19.39, 11.85, 13.23, 12.49,  2.85,  2.11, 21.81, 13.54,  2.25,
#          3.2 , 17.25]])

# %%
np.array([[3.0],[17.25]]).shape
# Out:
# (2, 1)
