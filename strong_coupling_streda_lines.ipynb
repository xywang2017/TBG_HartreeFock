# %%
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# np.NaN means non-convergent or no clear magnetic subbands
gaps2 = np.array([[i/2 for i in range(8)],
         [20.64,13.80,14.34,10.42,13.04,22.13,14.84,11.13]])


gaps37 = np.array([[3*i/7 for i in range(10)],
        [18.78,11.43,12.59,11.77,4.11,np.NaN,np.NaN,15.70,11.52,np.NaN]])
gaps37 = np.hstack([gaps37,np.array([[5/7,1.0,10/7,13/7,2.0,17/7,20/7,23/7,25/7],
                                     [0.04,4.16,9.49,13.62,0.94,20.83,1.05,5.03,1.91]])])


gaps25 = np.array([[2*i/5 for i in range(10)],
         [19.39,11.85,13.23,12.49,2.85,2.11,21.81,13.54,2.25,3.20]])
gaps25 = np.hstack([gaps25,np.array([[0.6,1.0,1.4,1.8,3.0,3.4],[0.69,1.60,10.33,14.99,17.25,12.72]])])


gaps3 = np.array([[i/3 for i in range(12)],
         [18.91,10.94,12.88,12.30,11.02,16.37,2.23,21.95,2.88,19.91,13.72,np.NaN]])


gaps27 = np.array([[2*i/7 for i in range(14)],
        [17.15,8.62,10.84,10.52,5.05,3.21,0.21,9.02,20.43,15.34,np.NaN,np.NaN,np.NaN,np.NaN]])
gaps27 = np.hstack([gaps27,np.array([[5/7,1.0,9/7,11/7,3.0,23/7,25/7],[0.6,0.95,10.54,14.93,19.96,14.31,2.47]])])


gaps4 = np.array([[i/4 for i in range(16)],
         [17.11,8.26,10.75,10.52,9.17,11.23,15.01,3.4,9.19,20.00,16.43,1.76,20.51,15.30,1.12,1.61]])

## 1.6 -> energies extremely close

gaps5 = np.array([[i/5 for i in range(20)],
         [16.86,7.56,10.27,10.00,12.51,8.59,12.08,14.64,2.39,3.65,
          9.41,19.27,3.34,1.14,0.59,20.27,16.28,1.32,2.89,0.68]])


gaps6 = np.array([[i/6 for i in range(24)],
         [16.70,6.94,9.74,9.48,0.18,12.65,7.98,12.65,14.02,1.36,
          5.26,1.47,9.49,18.29,3.81,1.39,3.00,0.06,19.63,16.75,3.80,3.14,2.07,0.01]])


gaps8 = np.array([[i/8 for i in range(32)],
         [15.41,4.76,7.54,7.11,0.84,1.44,0.27,11.66,6.06,12.15,
          11.42,2.22,1.71,4.83,1.52,1.48,7.85,14.99,3.51,2.22,
          1.15,0.36,0.85,0.002,15.85,15.53,4.17,0.86,1.00,1.43,0.93,1.62]])


gaps10 = np.array([[i/10 for i in range(16)],
        [15.61,4.41,6.78,6.63,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,np.NaN,5.82,13.05,10.49,2.62,1.88,np.NaN]])

# %%
fig = plt.figure(figsize=(6,4))
rat = 5
plt.axvline(0,ls=":",c="gray")
plt.axvline(1,ls=":",c="gray")
plt.axvline(2,ls=":",c="gray")
plt.axvline(3,ls=":",c="gray")
plt.scatter(gaps2[0], np.ones(gaps2.shape[1])/2, s=gaps2[1]**2/rat)
plt.scatter(gaps37[0], np.ones(gaps37.shape[1])/7*3, s=gaps37[1]**2/rat)
plt.scatter(gaps25[0], np.ones(gaps25.shape[1])/5*2, s=gaps25[1]**2/rat)
plt.scatter(gaps3[0], np.ones(gaps3.shape[1])/3, s=gaps3[1]**2/rat)
plt.scatter(gaps27[0], np.ones(gaps27.shape[1])/7*2, s=gaps27[1]**2/rat)
plt.scatter(gaps4[0], np.ones(gaps4.shape[1])/4, s=gaps4[1]**2/rat)
plt.scatter(gaps5[0], np.ones(gaps5.shape[1])/5, s=gaps5[1]**2/rat)
plt.scatter(gaps6[0], np.ones(gaps6.shape[1])/6, s=gaps6[1]**2/rat)
plt.scatter(gaps8[0], np.ones(gaps8.shape[1])/8, s=gaps8[1]**2/rat)
# plt.scatter(gaps10[0], np.ones(gaps10.shape[1])/10, s=gaps10[1]**2/rat)
plt.xlabel(r"$\nu$")
plt.ylabel(r"$\phi/\phi_0$")

plt.xlim(-0.3,4)
plt.ylim(0,0.6)
# plt.savefig("streda_lines_HF.pdf",transparent=True)
plt.show()

# %%
fig = plt.figure(figsize=(6,4)) 
plt.scatter([2,2],[1,1],s=[100**2,50**2],c=["r","g"])
plt.show()

# %%
st = [[0,0],[0,1],[0,2],[0,3],[1,-1],[1,0],[1,1],[1,2],[2,0],[2,1],[2,2],[3,0],[3,1]]

# %%
nus = np.zeros(len(st))
p, q = 1,8
for i in range(len(nus)):
    nus[i] = st[i][0] + st[i][1]*(p/q)

# %%
nus = np.unique(nus)

# %%
nus
# Out:
# array([0.   , 0.125, 0.25 , 0.375, 0.875, 1.   , 1.125, 1.25 , 2.   ,
#        2.125, 2.25 , 3.   , 3.125])

# %%
len(nus)
# Out:
# 13
